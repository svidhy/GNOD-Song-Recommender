# %% [markdown]
# #### Authentication

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import regex as re
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from pandas import json_normalize
# K-means
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
from sklearn.cluster import KMeans

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %% [markdown]
# #### authentication with secrets

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %% [markdown]
# # Extracting Large Playlists from spotify
#
# - https://open.spotify.com/playlist/1QfbJBydxHUJuQ0DeNNZTm - 8389 (Throwing error when json_normalize) so don't use
# - https://open.spotify.com/playlist/5xqpyfZyS1DVysoevdVyEn - 10,991
# - https://open.spotify.com/playlist/5S8SJdl1BDc0ugpkEvFsIL - 10,000
# - https://open.spotify.com/playlist/5oZjXwvrbAJ29Beza3h1bn - 10,000 (also throwing error json_normalize)
# - https://open.spotify.com/playlist/6yPiKpy7evrwvZodByKvM9 - 10,000
# - https://open.spotify.com/playlist/6FKDzNYZ8IW1pvYVF4zUN2 - 10,000

# %%
# we will need more songs for our clustering

playlist1 = sp.user_playlist_tracks("spotify", "5xqpyfZyS1DVysoevdVyEn")
playlist2 = sp.user_playlist_tracks("spotify", "5S8SJdl1BDc0ugpkEvFsIL")
playlist3 = sp.user_playlist_tracks("spotify", "6yPiKpy7evrwvZodByKvM9")
playlist4 = sp.user_playlist_tracks("spotify", "6FKDzNYZ8IW1pvYVF4zUN2")

# %%
# check the total
print(playlist1["total"])
print(playlist2["total"])
print(playlist3["total"])
print(playlist4["total"])
# Out:
# 10991
# 10000
# 10000
# 10000

# %%
# playlist['items'] contains the tracks on the playlist - check one by one
#playlist1['items']

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000)/1000) # respectful nap
    return tracks

# %%
# this will take at least around num_pages_in_playlist * (avg_sleep_time + processing_time) = 53 * (2+0.1) = 110 seconds

#all_tracks1 = get_playlist_tracks("4rnleEAOdmFAbRcNCgZMpY")
all_tracks1 = get_playlist_tracks("5xqpyfZyS1DVysoevdVyEn")
all_tracks2 = get_playlist_tracks("5S8SJdl1BDc0ugpkEvFsIL")
all_tracks3 = get_playlist_tracks("6yPiKpy7evrwvZodByKvM9")
all_tracks4 = get_playlist_tracks("6FKDzNYZ8IW1pvYVF4zUN2")

# %%
all_tracks5 = get_playlist_tracks("0R8V9dDuScYJ8zIUPHVj1b")

# %%
tracks1 = json_normalize(all_tracks1)
tracks2 = json_normalize(all_tracks2)
tracks3 = json_normalize(all_tracks3)
tracks4 = json_normalize(all_tracks4)

# %%
tracks4 = json_normalize(all_tracks4)
tracks5 = json_normalize(all_tracks5)

# %%
tracks2.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2017-11-20T02:52:18Z     False          None
# 1  2017-11-20T02:42:15Z     False          None
# 2  2017-11-20T02:36:40Z     False          None
# 3  2017-12-06T01:26:36Z     False          None
# 4  2017-11-20T02:36:14Z     False          None
#
#                       added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
# 1  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
# 2  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
# 3  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
# 4  https://open.spotify.com/user/twgeb7mzdcv4u8h1...
#
#                                        added_by.href  \
# 0  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
# 1  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
# 2  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
# 3  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
# 4  https://api.spotify.com/v1/users/twgeb7mzdcv4u...
#
#                  added_by.id added_by.type  \
# 0  twgeb7mzdcv4u8h191dxrvlpc          user
# 1  twgeb7mzdcv4u8h191dxrvlpc          user
# 2  twgeb7mzdcv4u8h191dxrvlpc          user
# 3  twgeb7mzdcv4u8h191dxrvlpc          user
# 4  twgeb7mzdcv4u8h191dxrvlpc          user
#
#                              added_by.uri track.album.album_type  \
# 0  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                 single
# 1  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                  album
# 2  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                  album
# 3  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                  album
# 4  spotify:user:twgeb7mzdcv4u8h191dxrvlpc                  album
#
#                                  track.album.artists  ... track.is_local  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...          False
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...          False
#
#          track.name track.popularity  \
# 0  ...Ready For It?                0
# 1      Life Changes               62
# 2         24K Magic               82
# 3       Galway Girl               81
# 4        Photograph               87
#
#                                    track.preview_url track.track  \
# 0                                               None        True
# 1                                               None        True
# 2  https://p.scdn.co/mp3-preview/3a76820d510fa5f8...        True
# 3  https://p.scdn.co/mp3-preview/9b7635464dc2caea...        True
# 4  https://p.scdn.co/mp3-preview/d90f4e5f15d8ed41...        True
#
#   track.track_number track.type                             track.uri  \
# 0                  1      track  spotify:track:7zgqtptZvhf8GEmdsM2vp2
# 1                  8      track  spotify:track:4Vxu50qVrQcycjRyJQaZLC
# 2                  1      track  spotify:track:6b8Be6ljOzmkOmFslEb23P
# 3                  6      track  spotify:track:0afhq8XCExXpqazXczTSve
# 4                  6      track  spotify:track:1HNkqx9Ahdgi1Ixy2xkKkL
#
#    video_thumbnail.url                                        artists_dfs
# 0                 None                                                ...
# 1                 None                                                ...
# 2                 None                                                ...
# 3                 None                                                ...
# 4                 None                                                ...
#
# [5 rows x 41 columns]

# %%
# we can even create a new column containing these DataFrames! KEEP song URI
# NOTE: need to change this function, since the columns names are now a bit different
def expand_list_dict(row):
    df = json_normalize(row['track.artists'])
    df['song_id'] = row['track.id']
    return df

# now we create a new dataframe with all these artists
def create_new_df(df):
    artist_df1 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri'])
    for mini_df in df['artists_dfs']:
        #display(mini_df)
        artist_df1 = pd.concat([artist_df1, mini_df], axis=0)
    return artist_df1

# %%
#tracks1['track.artists'][0]
tracks1['artists_dfs'] = tracks1.apply(expand_list_dict, axis=1)
tracks2['artists_dfs'] = tracks2.apply(expand_list_dict, axis=1)
tracks3['artists_dfs'] = tracks3.apply(expand_list_dict, axis=1)
tracks4['artists_dfs'] = tracks4.apply(expand_list_dict, axis=1)
#tracks2['artists_dfs'][3]

# %%
tracks5['artists_dfs'] = tracks5.apply(expand_list_dict, axis=1)

# %%
# # now we create a new dataframe with all these artists
# artist_df1 = pd.DataFrame(columns=['href', 'id', 'name', 'type', 'uri'])
# for mini_df in tracks1['artists_dfs']:
#     #display(val)
#     artist_df1 = pd.concat([artist_df2, mini_df], axis=0)
    
# artist_df2
artist_track1 = create_new_df(tracks1)

# %%
artist_track2 = create_new_df(tracks2)

# %%
artist_track2.shape
# Out:
# (12184, 7)

# %%
artist_track3 = create_new_df(tracks3)

# %%
artist_track4 = create_new_df(tracks4)

# %%
artist_track4.shape
# Out:
# (12736, 7)

# %%
artist_track5 = create_new_df(tracks5)

# %%
df_merged1 = pd.merge(left=tracks1,
                    right=artist_track1,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')
df_merged1.head()
# Out:
#                added_at  is_local primary_color  \
# 0  2016-04-13T17:09:41Z     False          None
# 1  2016-04-13T17:09:41Z     False          None
# 2  2016-04-13T17:09:41Z     False          None
# 3  2016-04-13T17:09:41Z     False          None
# 4  2016-04-13T17:09:41Z     False          None
#
#                   added_by.external_urls.spotify  \
# 0  https://open.spotify.com/user/secretagentfrog
# 1  https://open.spotify.com/user/secretagentfrog
# 2  https://open.spotify.com/user/secretagentfrog
# 3  https://open.spotify.com/user/secretagentfrog
# 4  https://open.spotify.com/user/secretagentfrog
#
#                                       added_by.href      added_by.id  \
# 0  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
# 1  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
# 2  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
# 3  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
# 4  https://api.spotify.com/v1/users/secretagentfrog  secretagentfrog
#
#   added_by.type                  added_by.uri track.album.album_type  \
# 0          user  spotify:user:secretagentfrog                  album
# 1          user  spotify:user:secretagentfrog                 single
# 2          user  spotify:user:secretagentfrog                  album
# 3          user  spotify:user:secretagentfrog                  album
# 4          user  spotify:user:secretagentfrog                  album
#
#                                  track.album.artists  ...  \
# 0  [{'external_urls': {'spotify': 'https://open.s...  ...
# 1  [{'external_urls': {'spotify': 'https://open.s...  ...
# 2  [{'external_urls': {'spotify': 'https://open.s...  ...
# 3  [{'external_urls': {'spotify': 'https://open.s...  ...
# 4  [{'external_urls': {'spotify': 'https://open.s...  ...
#
#                               track.uri video_thumbnail.url  \
# 0  spotify:track:3AA8xNhDC0MpqwkGX3EP5V                None
# 1  spotify:track:2i8lRhmZNKaM1ypHwRybuD                None
# 2  spotify:track:4flxgPC0426CEeSrzQIic0                None
# 3  spotify:track:1XHFob24QklIXtLRopKirJ                None
# 4  spotify:track:4JB847zlgViLq8tJIzRsZy                None
#
#                                          artists_dfs  \
# 0                                                ...
# 1                                                ...
# 2                                                ...
# 3                                                ...
# 4                                                ...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/1xU878Z1QtB...  1xU878Z1QtBldR7ru9owdU
# 1  https://api.spotify.com/v1/artists/2oWyxHNcxMc...  2oWyxHNcxMcrvNIHMX2apR
# 2  https://api.spotify.com/v1/artists/2UyhhfLOvfL...  2UyhhfLOvfLs7ZhzsAaNC3
# 3  https://api.spotify.com/v1/artists/1gkSl4XpHIH...  1gkSl4XpHIHI4I1WQbfXOE
# 4  https://api.spotify.com/v1/artists/3GpAL7oEFD3...  3GpAL7oEFD37IJDOOiirqy
#
#          name    type                                    uri  \
# 0     Phoenix  artist  spotify:artist:1xU878Z1QtBldR7ru9owdU
# 1     Radio 4  artist  spotify:artist:2oWyxHNcxMcrvNIHMX2apR
# 2  Mount Sims  artist  spotify:artist:2UyhhfLOvfLs7ZhzsAaNC3
# 3     Peaches  artist  spotify:artist:1gkSl4XpHIHI4I1WQbfXOE
# 4    Zongamin  artist  spotify:artist:3GpAL7oEFD37IJDOOiirqy
#
#                                external_urls.spotify                 song_id
# 0  https://open.spotify.com/artist/1xU878Z1QtBldR...  3AA8xNhDC0MpqwkGX3EP5V
# 1  https://open.spotify.com/artist/2oWyxHNcxMcrvN...  2i8lRhmZNKaM1ypHwRybuD
# 2  https://open.spotify.com/artist/2UyhhfLOvfLs7Z...  4flxgPC0426CEeSrzQIic0
# 3  https://open.spotify.com/artist/1gkSl4XpHIHI4I...  1XHFob24QklIXtLRopKirJ
# 4  https://open.spotify.com/artist/3GpAL7oEFD37IJ...  4JB847zlgViLq8tJIzRsZy
#
# [5 rows x 48 columns]

# %%
df_merged2 = pd.merge(left=tracks2,
                    right=artist_track2,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')

# %%
df_merged3 = pd.merge(left=tracks3,
                    right=artist_track3,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')

# %%
df_merged4 = pd.merge(left=tracks4,
                    right=artist_track4,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')

# %%
df_merged5 = pd.merge(left=tracks5,
                    right=artist_track5,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')

# %%
df_final1 = df_merged1[['track.name', 'name', 'song_id']]
df_final2 = df_merged2[['track.name', 'name', 'song_id']]
df_final3 = df_merged3[['track.name', 'name', 'song_id']]
df_final4 = df_merged4[['track.name', 'name', 'song_id']]
df_final5 = df_merged5[['track.name', 'name', 'song_id']]

# %%
df_final4.shape
type(df_final4)
# Out:
# pandas.core.frame.DataFrame

# %%
spotify_songs = pd.concat([df_final1,df_final2,df_final3,df_final4,df_final5], axis=0)
spotify_songs.shape
# Out:
# (67981, 3)

# %%
spotify_songs.drop_duplicates(inplace=True)

# %%
spotify_songs.shape
# Out:
# (55715, 3)

# %% [markdown]
# ### Audio features
#
# You can check here an explanation of the audio features: https://developer.spotify.com/documentation/web-api/reference/get-audio-features

# %%
# probably let them figure this out in the lab :-)
chunks = [(i, i+100) for i in range(0, len(spotify_songs), 100)]
chunks
audio_features_list = []
for chunk in chunks:
    spotify_songs['song_id'] = spotify_songs['song_id'].astype(str)
    id_list100 = spotify_songs['song_id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 55715

# %%
audio_features_spotify = json_normalize(audio_features_list)

# %%
audio_features_spotify.drop_duplicates(inplace=True) # duplicates because some songs have more artists

# %%
audio_features_spotify.shape
# Out:
# (46062, 18)

# %%
spotify_w_audio_ft = pd.merge(left=spotify_songs,
                        right=audio_features_spotify,
                        how='inner',
                        left_on='song_id',
                        right_on='id')
spotify_w_audio_ft
# Out:
#                                    track.name        name  \
# 0                       If I Ever Feel Better     Phoenix
# 1                    Dance To The Underground     Radio 4
# 2                                   How We Do  Mount Sims
# 3                          Fuck the Pain Away     Peaches
# 4                            Street Surgery 2    Zongamin
# ...                                       ...         ...
# 54946                                 New Toy   Metronomy
# 54947            Are Mums Mates - Bonus Track   Metronomy
# 54948             In The D.O.D. - Bonus Track   Metronomy
# 54949              Hear to Wear - Bonus Track   Metronomy
# 54950  Another Me To Mother You - Bonus Track   Metronomy
#
#                       song_id  danceability  energy   key  loudness  mode  \
# 0      3AA8xNhDC0MpqwkGX3EP5V         0.755  0.5530   6.0    -9.449   0.0
# 1      2i8lRhmZNKaM1ypHwRybuD         0.667  0.6670   7.0    -6.267   1.0
# 2      4flxgPC0426CEeSrzQIic0         0.826  0.6010  10.0    -3.966   0.0
# 3      1XHFob24QklIXtLRopKirJ         0.905  0.9450   4.0    -2.630   1.0
# 4      4JB847zlgViLq8tJIzRsZy         0.797  0.5360  11.0    -8.267   0.0
# ...                       ...           ...     ...   ...       ...   ...
# 54946  2GRHqnIHHCEsOd9fjD2bA5         0.465  0.0499   5.0   -22.532   1.0
# 54947  4mVCa7TD60hvECxO2ZpsDM         0.860  0.8240   7.0    -8.074   1.0
# 54948  2087SyreRbvQ5kUbRznrU8         0.753  0.9470   7.0    -5.084   1.0
# 54949  2tjvWiaD4X8oxUwaVoqDdQ         0.747  0.4470   0.0    -6.638   1.0
# 54950  3Glzw04ac6tjA8auLaNDBY         0.791  0.4470  11.0   -11.579   0.0
#
#        speechiness  acousticness  ...  liveness  valence    tempo  \
# 0           0.1070       0.04920  ...    0.0646    0.836  119.700
# 1           0.0388       0.00013  ...    0.0711    0.843  130.321
# 2           0.0515       0.19500  ...    0.0700    0.948  126.971
# 3           0.1370       0.03540  ...    0.0707    0.944  131.597
# 4           0.2660       0.03150  ...    0.1700    0.704  102.881
# ...            ...           ...  ...       ...      ...      ...
# 54946       0.0279       0.08300  ...    0.0795    0.106   76.311
# 54947       0.1920       0.03350  ...    0.0788    0.961  160.015
# 54948       0.1610       0.18400  ...    0.0769    0.979   92.497
# 54949       0.1340       0.00265  ...    0.0704    0.981  150.045
# 54950       0.0395       0.09490  ...    0.0983    0.695  125.296
#
#                  type                      id  \
# 0      audio_features  3AA8xNhDC0MpqwkGX3EP5V
# 1      audio_features  2i8lRhmZNKaM1ypHwRybuD
# 2      audio_features  4flxgPC0426CEeSrzQIic0
# 3      audio_features  1XHFob24QklIXtLRopKirJ
# 4      audio_features  4JB847zlgViLq8tJIzRsZy
# ...               ...                     ...
# 54946  audio_features  2GRHqnIHHCEsOd9fjD2bA5
# 54947  audio_features  4mVCa7TD60hvECxO2ZpsDM
# 54948  audio_features  2087SyreRbvQ5kUbRznrU8
# 54949  audio_features  2tjvWiaD4X8oxUwaVoqDdQ
# 54950  audio_features  3Glzw04ac6tjA8auLaNDBY
#
#                                         uri  \
# 0      spotify:track:3AA8xNhDC0MpqwkGX3EP5V
# 1      spotify:track:2i8lRhmZNKaM1ypHwRybuD
# 2      spotify:track:4flxgPC0426CEeSrzQIic0
# 3      spotify:track:1XHFob24QklIXtLRopKirJ
# 4      spotify:track:4JB847zlgViLq8tJIzRsZy
# ...                                     ...
# 54946  spotify:track:2GRHqnIHHCEsOd9fjD2bA5
# 54947  spotify:track:4mVCa7TD60hvECxO2ZpsDM
# 54948  spotify:track:2087SyreRbvQ5kUbRznrU8
# 54949  spotify:track:2tjvWiaD4X8oxUwaVoqDdQ
# 54950  spotify:track:3Glzw04ac6tjA8auLaNDBY
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/3AA8xNhDC0Mp...
# 1      https://api.spotify.com/v1/tracks/2i8lRhmZNKaM...
# 2      https://api.spotify.com/v1/tracks/4flxgPC0426C...
# 3      https://api.spotify.com/v1/tracks/1XHFob24QklI...
# 4      https://api.spotify.com/v1/tracks/4JB847zlgViL...
# ...                                                  ...
# 54946  https://api.spotify.com/v1/tracks/2GRHqnIHHCEs...
# 54947  https://api.spotify.com/v1/tracks/4mVCa7TD60hv...
# 54948  https://api.spotify.com/v1/tracks/2087SyreRbvQ...
# 54949  https://api.spotify.com/v1/tracks/2tjvWiaD4X8o...
# 54950  https://api.spotify.com/v1/tracks/3Glzw04ac6tj...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/3AA8...    266600.0
# 1      https://api.spotify.com/v1/audio-analysis/2i8l...    243213.0
# 2      https://api.spotify.com/v1/audio-analysis/4flx...    234000.0
# 3      https://api.spotify.com/v1/audio-analysis/1XHF...    250693.0
# 4      https://api.spotify.com/v1/audio-analysis/4JB8...    224800.0
# ...                                                  ...         ...
# 54946  https://api.spotify.com/v1/audio-analysis/2GRH...    177640.0
# 54947  https://api.spotify.com/v1/audio-analysis/4mVC...    134693.0
# 54948  https://api.spotify.com/v1/audio-analysis/2087...    197987.0
# 54949  https://api.spotify.com/v1/audio-analysis/2tjv...    207573.0
# 54950  https://api.spotify.com/v1/audio-analysis/3Glz...    254430.0
#
#        time_signature
# 0                 4.0
# 1                 4.0
# 2                 4.0
# 3                 4.0
# 4                 4.0
# ...               ...
# 54946             4.0
# 54947             4.0
# 54948             4.0
# 54949             4.0
# 54950             4.0
#
# [54951 rows x 21 columns]

# %%
spotify_w_audio_ft.isna().sum()
# Out:
# track.name          0
# name                0
# song_id             0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# dtype: int64

# %% [markdown]
# ## Extracting from Saved Spotify csv

# %%
top_songs = pd.read_csv('top_songs.csv')
spotify_songs = pd.read_csv('spotify_songs.csv')

# %%
spotify_songs_num = spotify_songs.select_dtypes(include='number')

# %%
spotify_songs_num.shape
# Out:
# (54951, 13)

# %% [markdown]
# ### Scaling the data as the values are in dissimilar range

# %%
from sklearn.preprocessing import StandardScaler
transformer = StandardScaler().fit(spotify_songs_num)
X_prep = transformer.transform(spotify_songs_num)

# %%
X_prep
# Out:
# array([[ 1.09803858, -0.56152523,  0.20786871, ..., -0.06686642,
#          0.11009111,  0.18360596],
#        [ 0.60508148, -0.04309072,  0.48587862, ...,  0.31398741,
#         -0.02068364,  0.18360596],
#        [ 1.49576534, -0.34323702,  1.31990837, ...,  0.19386121,
#         -0.07220062,  0.18360596],
#        ...,
#        [ 1.08683501,  1.23025719,  0.48587862, ..., -1.04232699,
#         -0.27357706,  0.18360596],
#        [ 1.0532243 , -1.04357837, -1.46019078, ...,  1.02126176,
#         -0.21997435,  0.18360596],
#        [ 1.29970285, -1.04357837,  1.59791828, ...,  0.13379811,
#          0.04203926,  0.18360596]])

# %%
pd.DataFrame(X_prep,columns=spotify_songs_num.columns).head()
# Out:
#    danceability    energy       key  loudness      mode  speechiness  \
# 0      1.098039 -0.561525  0.207869 -0.444116 -1.283590     0.227392
# 1      0.605081 -0.043091  0.485879  0.334671  0.779065    -0.509890
# 2      1.495765 -0.343237  1.319908  0.897835 -1.283590    -0.372595
# 3      1.938306  1.221162 -0.348151  1.224818  0.779065     0.551709
# 4      1.333314 -0.638836  1.597918 -0.154825 -1.283590     1.946275
#
#    acousticness  instrumentalness  liveness   valence     tempo  duration_ms  \
# 0     -0.566729         -0.588621 -0.816667  1.563041 -0.066866     0.110091
# 1     -0.742491         -0.595556 -0.777741  1.591035  0.313987    -0.020684
# 2     -0.044491         -0.607573 -0.784329  2.010951  0.193861    -0.072201
# 3     -0.616158         -0.591058 -0.780137  1.994954  0.359743     0.021143
# 4     -0.630128         -0.607493 -0.185470  1.035147 -0.669972    -0.123645
#
#    time_signature
# 0        0.183606
# 1        0.183606
# 2        0.183606
# 3        0.183606
# 4        0.183606

# %% [markdown]
# ### Choosing K

# %%
import numpy as np
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_init = 10, n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
from sklearn.metrics import silhouette_score
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_init = 10, n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')
# Out:
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Text(0.5, 1.0, 'Slhouette score showing the optimal k')

# %% [markdown]
# ### Choosing the cluster number using K-means
# Based on inertia and the silhouette score, the number of clusters is either 9 or 10

# %%
num_clusters = 10
kmeans = KMeans(n_clusters=num_clusters, random_state=1234)
kmeans.fit(X_prep)
# Out:
# /Users/vidhya/opt/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=10, random_state=1234)

# %%
# Predicting / assigning the clusters:
clusters = kmeans.predict(X_prep)

# Check the size of the clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     7228
# 1    10387
# 2     2533
# 3     7770
# 4       99
# 5     7078
# 6     3527
# 7     3294
# 8      381
# 9    12654
# Name: count, dtype: int64

# %%
clusters
# Out:
# array([1, 9, 1, ..., 9, 0, 0], dtype=int32)

# %%
plt.figure(figsize=(5, 5))
plt.scatter(X_prep[:, 0], X_prep[:, 9], c=clusters,alpha=0.6)
plt.show()

# %%
# %%time
kmeans = KMeans(n_clusters=10,
                init="random",
                n_init= 1,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=10,
                tol=0,
                random_state=1234)
kmeans.fit(X_prep)
print(kmeans.inertia_)
# Out:
# 426787.04133928317
# CPU times: user 79.1 ms, sys: 19.5 ms, total: 98.6 ms
# Wall time: 22.5 ms

# %%
spotify_songs['cluster'] = clusters

# %%
spotify_songs['song_and_artist'] = spotify_songs['track.name'] + " by " + spotify_songs['name']

# %%
spotify_songs.head()
# Out:
#                  track.name        name                 song_id  danceability  \
# 0     If I Ever Feel Better     Phoenix  3AA8xNhDC0MpqwkGX3EP5V         0.755
# 1  Dance To The Underground     Radio 4  2i8lRhmZNKaM1ypHwRybuD         0.667
# 2                 How We Do  Mount Sims  4flxgPC0426CEeSrzQIic0         0.826
# 3        Fuck the Pain Away     Peaches  1XHFob24QklIXtLRopKirJ         0.905
# 4          Street Surgery 2    Zongamin  4JB847zlgViLq8tJIzRsZy         0.797
#
#    energy   key  loudness  mode  speechiness  acousticness  ...    tempo  \
# 0   0.553   6.0    -9.449   0.0       0.1070       0.04920  ...  119.700
# 1   0.667   7.0    -6.267   1.0       0.0388       0.00013  ...  130.321
# 2   0.601  10.0    -3.966   0.0       0.0515       0.19500  ...  126.971
# 3   0.945   4.0    -2.630   1.0       0.1370       0.03540  ...  131.597
# 4   0.536  11.0    -8.267   0.0       0.2660       0.03150  ...  102.881
#
#              type                      id  \
# 0  audio_features  3AA8xNhDC0MpqwkGX3EP5V
# 1  audio_features  2i8lRhmZNKaM1ypHwRybuD
# 2  audio_features  4flxgPC0426CEeSrzQIic0
# 3  audio_features  1XHFob24QklIXtLRopKirJ
# 4  audio_features  4JB847zlgViLq8tJIzRsZy
#
#                                     uri  \
# 0  spotify:track:3AA8xNhDC0MpqwkGX3EP5V
# 1  spotify:track:2i8lRhmZNKaM1ypHwRybuD
# 2  spotify:track:4flxgPC0426CEeSrzQIic0
# 3  spotify:track:1XHFob24QklIXtLRopKirJ
# 4  spotify:track:4JB847zlgViLq8tJIzRsZy
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3AA8xNhDC0Mp...
# 1  https://api.spotify.com/v1/tracks/2i8lRhmZNKaM...
# 2  https://api.spotify.com/v1/tracks/4flxgPC0426C...
# 3  https://api.spotify.com/v1/tracks/1XHFob24QklI...
# 4  https://api.spotify.com/v1/tracks/4JB847zlgViL...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3AA8...    266600.0
# 1  https://api.spotify.com/v1/audio-analysis/2i8l...    243213.0
# 2  https://api.spotify.com/v1/audio-analysis/4flx...    234000.0
# 3  https://api.spotify.com/v1/audio-analysis/1XHF...    250693.0
# 4  https://api.spotify.com/v1/audio-analysis/4JB8...    224800.0
#
#   time_signature cluster                      song_and_artist
# 0            4.0       1     If I Ever Feel Better by Phoenix
# 1            4.0       9  Dance To The Underground by Radio 4
# 2            4.0       1              How We Do by Mount Sims
# 3            4.0       9        Fuck the Pain Away by Peaches
# 4            4.0       6         Street Surgery 2 by Zongamin
#
# [5 rows x 23 columns]

# %%
spotify_with_cluster = spotify_songs[['song_and_artist', 'cluster']]
spotify_with_cluster
# Out:
#                                          song_and_artist  cluster
# 0                       If I Ever Feel Better by Phoenix        1
# 1                    Dance To The Underground by Radio 4        9
# 2                                How We Do by Mount Sims        1
# 3                          Fuck the Pain Away by Peaches        9
# 4                           Street Surgery 2 by Zongamin        6
# ...                                                  ...      ...
# 54946                               New Toy by Metronomy        2
# 54947          Are Mums Mates - Bonus Track by Metronomy        9
# 54948           In The D.O.D. - Bonus Track by Metronomy        9
# 54949            Hear to Wear - Bonus Track by Metronomy        0
# 54950  Another Me To Mother You - Bonus Track by Metr...        0
#
# [54951 rows x 2 columns]

# %%
import pickle
pickle.dump(kmeans, open('kmean.pkl', 'wb'))
pickle.dump(transformer, open('scaler.pkl', 'wb'))

# %%
type(transformer)
# Out:
# sklearn.preprocessing._data.StandardScaler
